# %%
a = 2
b =3
area = 1/2*(b*a)
print(area)
# Out:
# 3.0

# %%
# Out:
# enter any no.0
# hello

# %%
b =int(input("enter the value of base: "))
h =int(input("enter the value of height: "))
area = 1/2*(b*h)
print(area)
# Out:
# enter the value of base: 60
# enter the value of height: 120
# 3600.0

# %%
r = int(input("enter the value of radius: "))
area= 3.14*r*r
print(area)
# Out:
# enter the value of radius: 9
# 254.34

# %%
#Write a Python program to find the area of a rectangle given that its length is 10 units and breadth is 20 units.
l =20 # l is length 
b = 10 

'''area of rect is thisthis this oklsdsd'''

area = l*b
print(area)
# Out:
# 200

# %%
#use type() to know data type
a = 123
b =12.6
print(type(b))
# Out:
# <class 'float'>

# %%
#create and print list
L1 = [12,3.5,"python",11232]
print(L1)
# Out:
# [12, 3.5, 'python', 11232]

# %%
T1 = (12,3.5,"python",11232)
print(T1)
# Out:
# (12, 3.5, 'python', 11232)

# %%
x y z = 5000 6000 7000
print(x y z)
# Out:
#   File "C:\Users\AMRITA\AppData\Local\Temp/ipykernel_11100/242773924.py", line 1
#     x y z = 5000 6000 7000
#       ^
# SyntaxError: invalid syntax

# %%
_val = 12
val =12
_try_ =12
try = 12

# %%
a = 13
print(a**2)
# Out:
# 169

# %%
try = 12
print(try)
# Out:
#   File "C:\Users\AMRITA\AppData\Local\Temp/ipykernel_11100/3440201125.py", line 1
#     try = 12
#         ^
# SyntaxError: invalid syntax

# %%
xyz=5000
x,y,z=5000,6000,7000
x_y_z=5000
x y z = 5000 6000 7000
